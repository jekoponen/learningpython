# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'tests.ipynb']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1=df1.set_index("ID")

# %%
df2 = pandas.read_json("supermarkets.json")
df2=df2.set_index("ID")

# %%
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3=df3.set_index("ID")

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4=df4.set_index("ID")

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5=df5.set_index("ID")
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.loc["2":"4","City":"Country"]
# Out:
#              City             State Country
# ID
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA

# %%
df5.loc[:,"Country"]
# Out:
# ID
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object

# %%
list(df5.loc[1:,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-9093e73c253d> in <module>()
# ----> 1 list(df5.loc[1:,:])
#
# c:\users\juha.koponen\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# c:\users\juha.koponen\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     876                 continue
#     877
# --> 878             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     879
#     880         return retval
#
# ...

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.iloc[1:4,2:5]
# Out:
#                Country          Name  Employees
# Address
# 735 Dolores St     USA   Bready Shop         15
# 332 Hill St        USA   Super River         25
# 3995 23rd St       USA    Ben's Shop         10

# %%
df5.ix[1:4,"City":"Name"]
# Out:
# c:\users\juha.koponen\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#              City             State Country          Name
# ID
# 1   San Francisco          CA 94114     USA       Madeira
# 2   San Francisco          CA 94119     USA   Bready Shop
# 3   San Francisco  California 94114     USA   Super River
# 4   San Francisco          CA 94114     USA    Ben's Shop

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.drop("State",1) #argument 1 for dropping comlumns, 0 for rows
# Out:
#             Address           City Country          Name  Employees
# ID
# 1      3666 21st St  San Francisco     USA       Madeira          8
# 2    735 Dolores St  San Francisco     USA   Bready Shop         15
# 3       332 Hill St  San Francisco     USA   Super River         25
# 4      3995 23rd St  San Francisco     USA    Ben's Shop         10
# 5   1056 Sanchez St  San Francisco     USA       Sanchez         12
# 6   551 Alvarado St  San Francisco     USA    Richvalley         20

# %%
df5.drop(5,0) #argument 1 for dropping comlumns, 0 for rows
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 6          20

# %%
df5=df5.set_index("Address")

# %%
df5.shape
# Out:
# (6, 5)

# %%
df5["Continent"]=df5.shape[0]*["North America"] #New column has to haw as many values in list as it has rows. Method .shape returns number of indexies in list[rows,columns]

# %%
df5
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df6=df5
df6["Continent"]=df6["Country"] + "," + "North America"
df6
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA,North America
# 735 Dolores St          15  USA,North America
# 332 Hill St             25  USA,North America
# 3995 23rd St            10  USA,North America
# 1056 Sanchez St         12  USA,North America
# 551 Alvarado St         20  USA,North America

# %%
#Adding row: first you hava to make transpose for dataFrame and add new "row" as new column and the transpose back
df7=df6
df7_t=df7.T    #.T is transpose method
df7_t["666 Main St"]=["Houston","Texas","USA","Super saver","14","USA,North America"] #Create new column named as Address and insert values for all rows

# %%
df7_t #here is added column
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# Employees                 10                 12                 20
# Continent  USA,North America  USA,North America  USA,North America
#
# ...

# %%
df7=df7_t.T #after addin new column transpose dataFrame and replace old wit added row
df7
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
# 666 Main St            Houston             Texas     USA   Super saver
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 735 Dolores St         15  USA,North America
# 332 Hill St            25  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# 666 Main St            14  USA,North America

# %%
for i in crd_df.values:
    print(type(i[0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(type(crd_df.values))
# Out:
# <class 'numpy.ndarray'>

# %%
https://github.com/lvoogdt/Leaflet.awesome-markers

# %%
folium.Icon?
